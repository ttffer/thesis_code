# %%
import matplotlib.pyplot as plt

# %%
#LUT 
our_13={"4x4":2091,"5x5":2398,"6x6":2666}
our_29={"4x4":7372,"5x5":8083,"6x6":8987}
our_37={"4x4":12900,"5x5":14254,"6x6":15950}

pre_13={"4x4":24720,"5x5":38600,"6x6":55584}
pre_29={"4x4":60848,"5x5":95075,"6x6":211104}
pre_37={"4x4":161200,"5x5":251875,"6x6":362700}

# %%
# log
our_13.keys()
plt.figure(figsize=(10,20))

plt.subplot(311)
oa13,=plt.plot(our_13.keys(), [1963,2198,2373]) #our_A=13 
pa13,=plt.plot(our_13.keys(),[24720,38600,55584]) #pre_A=13 
plt.yscale('log')
plt.title('A=13')
plt.ylabel('LUT numbers')
plt.xlabel('Array type')
plt.grid(True)
plt.legend([pa13,oa13],["pre_A=13 ","our_A=13 "])

plt.subplot(312)
oa29,=plt.plot(our_13.keys(), [6899,7323,7874]) #our_A=29 
pa29,=plt.plot(our_13.keys(),[60848,95075,211104]) #pre_A=29
plt.yscale('log')
plt.title('A=29')
plt.ylabel('LUT numbers')
plt.xlabel('Array type')
plt.grid(True)
plt.legend([pa29,oa29],["pre_A=29 ","our_A=29 "])

plt.subplot(313)
oa37,=plt.plot(our_13.keys(), [11263,11967,12817]) #our_A=37 
pa37,=plt.plot(our_13.keys(),[161200,251875,362700]) #pre_A=37
plt.yscale('log')
plt.title('A=37')
plt.ylabel('LUT numbers')
plt.xlabel('Array type')
plt.grid(True)
plt.legend([pa37,oa37],["pre_A=37 ","our_A=37 "])
#plt.axis([10, 40, 0, 0.03])
plt.savefig("C:/Users/E411_71/Desktop/2dpc/Evaluation131.png", bbox_inches='tight')

# %%
A=[13,29,37]
for ele in S:
    print

# %%
# log
our_13.keys()
plt.figure(figsize=(10,10))


oa13,=plt.plot(our_13.keys(), [1963,2198,2373]) #our_A=13 
pa13,=plt.plot(our_13.keys(),[24720,38600,55584]) #pre_A=13 

oa29,=plt.plot(our_13.keys(), [6899,7323,7874]) #our_A=29 
pa29,=plt.plot(our_13.keys(),[60848,95075,211104]) #pre_A=29

oa37,=plt.plot(our_13.keys(), [11263,11967,12817]) #our_A=37 
pa37,=plt.plot(our_13.keys(),[161200,251875,362700]) #pre_A=37
plt.yscale('log')
plt.title('All in one plot')
plt.ylabel('LUT numbers')
plt.xlabel('Array type')
plt.grid(True)
plt.legend([pa37,pa29,pa13,oa37,oa29,oa13],["pre_A=37 ","pre_A=29 ","pre_A=13 ","our_A=37 ","our_A=29 ","our_A=13 "])
#plt.axis([10, 40, 0, 0.03])
plt.savefig("C:/Users/E411_71/Desktop/2dpc/Evaluation_in_one.png", bbox_inches='tight')

# %%
import numpy as np
x=[16,25,36]

# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %%
# log



plt.plot(our_13.keys(), [6899,7323,7874]) #our_A=29 
plt.plot(our_13.keys(),[60848,95075,211104]) #pre_A=29


plt.yscale('log')
plt.title('log')
#plt.axis([10, 40, 0, 0.03])
plt.grid(True)

# %%
# log

plt.subplot(111)
plt.plot(our_13.keys(), [1963,2198,2373]) #our_A=13 
plt.plot(our_13.keys(),[24720,38600,55584]) #pre_A=13 

plt.plot(our_13.keys(), [6899,7323,7874]) #our_A=29 
plt.plot(our_13.keys(),[60848,95075,211104]) #pre_A=29

plt.plot(our_13.keys(), [11263,11967,12817]) #our_A=37 
plt.plot(our_13.keys(),[161200,251875,362700]) #pre_A=37

plt.yscale('log')
plt.title('log')
#plt.axis([10, 40, 0, 0.03])
plt.grid(True)

# %%
plt.subplot(131)
for array,number in our_13.items():
    plt.bar(array, number)

# %%
plt.subplot(131)
for array,number in our_29.items():
    plt.bar(array, number)

# %%
plt.subplot(131)
for array,number in our_37.items():
    plt.bar(array, number)
